# %%
import pandas as pd

# %%
df = pd.read_excel(r'DataAlumni.csv')
df
# Out:
#     No       Nim                 Nama                                TTL  \
# 0    1   9018263      Puguh Drajat E.P        Purworejo, 4 November 1989
# 1    2  12022030  Arsyad Cahya Subrata              Bantul, 21 juni 1994
# 2    3  12020021          Yesi Novela          Tempilang, 1 januari 1995
# 3    4   9018269       Pandu Herwijaya         Lampung, 19 Desember 1990
# 4    5   9018109        Anjar Prasetyo        Gunungkidul, 27 April 1991
# 5    6   9020026   Moh. Dadi Kurniawan         Savanajaya, 27 Maret 1992
# 6    7  12018060        Martin Sarlina              Lepak, 23 Maret 1994
# 7    8  11018022      Yan Adhi Permadi              Jepara, 22 juni 1993
# 8    9   9018212       Achicha Wahyuni           Yogyakarta, 3 juni 1991
# 9   10   9018301   Yayan Tisna Permadi      Purbalingga, 08 Oktober 1991
# 10  11  12022020        Muh. Rama dhai          Pekanbaru, 29 Maret 1992
# 11  12  12022038           Nurwahyuddi  Dili, timor-timur/ 13 April 1995
# ...

# %%
df.columns = ['No', 'NIM', 'Nama', 'TTL', 'Fakultas', 'Alamat', 'Masuk', 'Lulus', 'Status', 'LamaTunggu', 'Gaji', 'TOEFL', 'IPK']

# %%
mean_IPK = df.IPK.mean()
mean_TOEFL = df.TOEFL.mean()
mean_Masa = df.LamaTunggu.mean()
mean_Gaji = df.Gaji.mean()

# %%
df.IPK.fillna(mean_IPK, inplace = True)
df.TOEFL.fillna(mean_TOEFL, inplace = True)
df.LamaTunggu.fillna(mean_Masa, inplace = True)
df.Gaji.fillna(mean_Gaji, inplace = True)
df
# Out:
#     No       NIM                  Nama                               TTL  \
# 0    1   9018263      Puguh Drajat E.P        Purworejo, 4 November 1989
# 1    2  12022030  Arsyad Cahya Subrata              Bantul, 21 juni 1994
# 2    3  12020021          Yesi Novela          Tempilang, 1 januari 1995
# 3    4   9018269       Pandu Herwijaya         Lampung, 19 Desember 1990
# 4    5   9018109        Anjar Prasetyo        Gunungkidul, 27 April 1991
# 5    6   9020026   Moh. Dadi Kurniawan         Savanajaya, 27 Maret 1992
# 6    7  12018060        Martin Sarlina              Lepak, 23 Maret 1994
# 7    8  11018022      Yan Adhi Permadi              Jepara, 22 juni 1993
# 8    9   9018212       Achicha Wahyuni           Yogyakarta, 3 juni 1991
# 9   10   9018301   Yayan Tisna Permadi      Purbalingga, 08 Oktober 1991
# 10  11  12022020        Muh. Rama dhai          Pekanbaru, 29 Maret 1992
# 11  12  12022038           Nurwahyuddi  Dili, timor-timur/ 13 April 1995
# ...

# %%
def_status = 'Mahasiswa'
DATA.Status.fillna(def_status, inplace = True)
df
# Out:
#     No       NIM                  Nama                               TTL  \
# 0    1   9018263      Puguh Drajat E.P        Purworejo, 4 November 1989
# 1    2  12022030  Arsyad Cahya Subrata              Bantul, 21 juni 1994
# 2    3  12020021          Yesi Novela          Tempilang, 1 januari 1995
# 3    4   9018269       Pandu Herwijaya         Lampung, 19 Desember 1990
# 4    5   9018109        Anjar Prasetyo        Gunungkidul, 27 April 1991
# 5    6   9020026   Moh. Dadi Kurniawan         Savanajaya, 27 Maret 1992
# 6    7  12018060        Martin Sarlina              Lepak, 23 Maret 1994
# 7    8  11018022      Yan Adhi Permadi              Jepara, 22 juni 1993
# 8    9   9018212       Achicha Wahyuni           Yogyakarta, 3 juni 1991
# 9   10   9018301   Yayan Tisna Permadi      Purbalingga, 08 Oktober 1991
# 10  11  12022020        Muh. Rama dhai          Pekanbaru, 29 Maret 1992
# 11  12  12022038           Nurwahyuddi  Dili, timor-timur/ 13 April 1995
# ...

# %%
for index, row in df.iterrows():
    df.loc[index, 'Tahun Lahir'] = row['TTL'][-4:]
df
# Out:
#     No       NIM                  Nama                               TTL  \
# 0    1   9018263      Puguh Drajat E.P        Purworejo, 4 November 1989
# 1    2  12022030  Arsyad Cahya Subrata              Bantul, 21 juni 1994
# 2    3  12020021          Yesi Novela          Tempilang, 1 januari 1995
# 3    4   9018269       Pandu Herwijaya         Lampung, 19 Desember 1990
# 4    5   9018109        Anjar Prasetyo        Gunungkidul, 27 April 1991
# 5    6   9020026   Moh. Dadi Kurniawan         Savanajaya, 27 Maret 1992
# 6    7  12018060        Martin Sarlina              Lepak, 23 Maret 1994
# 7    8  11018022      Yan Adhi Permadi              Jepara, 22 juni 1993
# 8    9   9018212       Achicha Wahyuni           Yogyakarta, 3 juni 1991
# 9   10   9018301   Yayan Tisna Permadi      Purbalingga, 08 Oktober 1991
# 10  11  12022020        Muh. Rama dhai          Pekanbaru, 29 Maret 1992
# 11  12  12022038           Nurwahyuddi  Dili, timor-timur/ 13 April 1995
# ...

# %%
from datetime import datetime
now = datetime.now()

now.year
for index, row in df.iterrows():
    df.loc[index, 'Umur'] = now.year - int(row['Tahun Lahir'])
    
df
# Out:
#     No       NIM                  Nama                               TTL  \
# 0    1   9018263      Puguh Drajat E.P        Purworejo, 4 November 1989
# 1    2  12022030  Arsyad Cahya Subrata              Bantul, 21 juni 1994
# 2    3  12020021          Yesi Novela          Tempilang, 1 januari 1995
# 3    4   9018269       Pandu Herwijaya         Lampung, 19 Desember 1990
# 4    5   9018109        Anjar Prasetyo        Gunungkidul, 27 April 1991
# 5    6   9020026   Moh. Dadi Kurniawan         Savanajaya, 27 Maret 1992
# 6    7  12018060        Martin Sarlina              Lepak, 23 Maret 1994
# 7    8  11018022      Yan Adhi Permadi              Jepara, 22 juni 1993
# 8    9   9018212       Achicha Wahyuni           Yogyakarta, 3 juni 1991
# 9   10   9018301   Yayan Tisna Permadi      Purbalingga, 08 Oktober 1991
# 10  11  12022020        Muh. Rama dhai          Pekanbaru, 29 Maret 1992
# 11  12  12022038           Nurwahyuddi  Dili, timor-timur/ 13 April 1995
# ...

# %%
for index, row in df.iterrows():
    df.loc[index, 'Masa Studi'] = row['Lulus'] - row['Masuk']
df
# Out:
#     No       NIM                  Nama                               TTL  \
# 0    1   9018263      Puguh Drajat E.P        Purworejo, 4 November 1989
# 1    2  12022030  Arsyad Cahya Subrata              Bantul, 21 juni 1994
# 2    3  12020021          Yesi Novela          Tempilang, 1 januari 1995
# 3    4   9018269       Pandu Herwijaya         Lampung, 19 Desember 1990
# 4    5   9018109        Anjar Prasetyo        Gunungkidul, 27 April 1991
# 5    6   9020026   Moh. Dadi Kurniawan         Savanajaya, 27 Maret 1992
# 6    7  12018060        Martin Sarlina              Lepak, 23 Maret 1994
# 7    8  11018022      Yan Adhi Permadi              Jepara, 22 juni 1993
# 8    9   9018212       Achicha Wahyuni           Yogyakarta, 3 juni 1991
# 9   10   9018301   Yayan Tisna Permadi      Purbalingga, 08 Oktober 1991
# 10  11  12022020        Muh. Rama dhai          Pekanbaru, 29 Maret 1992
# 11  12  12022038           Nurwahyuddi  Dili, timor-timur/ 13 April 1995
# ...

# %%
for index, row in df.iterrows():
    if row['IPK'] > 3.50:
        df.loc[index, 'Nilai_IPK'] = 'Maksimum'
    elif row['IPK'] >= 2.75:
        df.loc[index, 'Nilai_IPK'] = 'Rata - Rata'
    else:
        df.loc[index, 'Nilai_IPK'] = 'Minimum'
df[['NIM', 'IPK', 'Nilai_IPK']]
# Out:
#          NIM       IPK    Nilai_IPK
# 0    9018263  2.130000      Minimum
# 1   12022030  3.156154  Rata - Rata
# 2   12020021  3.156154  Rata - Rata
# 3    9018269  2.750000  Rata - Rata
# 4    9018109  3.156154  Rata - Rata
# 5    9020026  3.240000  Rata - Rata
# 6   12018060  3.270000  Rata - Rata
# 7   11018022  3.200000  Rata - Rata
# 8    9018212  3.240000  Rata - Rata
# 9    9018301  3.060000  Rata - Rata
# 10  12022020  3.470000  Rata - Rata
# 11  12022038  3.620000     Maksimum
# 12  12019039  3.320000  Rata - Rata
# 13  11018111  3.140000  Rata - Rata
# 14   9018135  2.990000  Rata - Rata
# 15  12018161  3.600000     Maksimum

# %%
for index, row in df.iterrows():
    if row['toel'] > 500:
        df.loc[index, 'Kategori'] = 'T3'
    elif row['TOEFL'] >= 450:
        df.loc[index, 'Kategori'] = 'T2'
    else:
        df.loc[index, 'Kategori'] = 'T1'
df[['NIM', 'IPK', 'TOEFL', 'Kategori']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'toel'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
for index, row in df.iterrows():
    if row['LamaTunggu'] >= 9:
        df.loc[index, 'LAMA TUNGGU'] = 'W4'
    elif row['LamaTunggu'] >= 6:
        df.loc[index, 'LAMA TUNGGU'] = 'W3'
    elif row['LamaTunggu'] >= 3:
        df.loc[index, 'LAMA TUNGGU'] = 'W2'
    else:
        df.loc[index, 'LAMA TUNGGU'] = 'W1'
df[['NIM', 'IPK', 'TOEFL', 'LAMA TUNGGU']]

# %%
for index, row in df.iterrows():
    if row['Masa Studi'] >= 4:
        DATA.loc[index, 'MASA STUDI'] = 'TTW'
    else:
        df.loc[index, 'MASA STUDI'] = 'TW'
df[['NIM', 'IPK', 'TOEFL', 'LAMA TUNGGU', 'MASA STUDI']]

# %%
for index, row in df.iterrows():
    if row['Umur'] >= 25:
        df.loc[index, 'UMUR'] = 'TP'
    else:
        df.loc[index, 'UMUR'] = 'UP'
df[['NIM', 'IPK', 'TOEFL', 'LAMA TUNGGU', 'MASA STUDI', 'UMUR']]

# %%
for index, row in df.iterrows():
    if row['Gaji'] >= 1572200:
        df.loc[index, 'GAJI'] = 'A.UMR'
    else:
        df.loc[index, 'GAJI'] = 'B.UMR'
df[['NIM', 'IPK', 'TOEFL', 'LAMA TUNGGU', 'MASA STUDI', 'UMUR', 'GAJI']]

# %%
df

# %% [markdown]
# # Transformasi One-Hot Encoding

# %%
dummies = pd.get_dummies(df.Status)
dummies.columns = ['Freelance', 'Guru', 'Mahasiswa', 'Swasta', 'Wiraswasta']
dummies
